# %% [markdown]
# #<center>UCA - Licenciatura en Gestión de Negocios Digitales</center>
# #<center>Arquitectura de la Tecnología Informática</center>
# ##<center>Práctica 4 - FUNCIONES</center>

# %% [markdown]
# ---
#
#
#
# Para resolver los ejercicios, a continuación de cada enunciado, agrega una celda de +Código o +Texto según se pida un programa o una descripción.
#
#
# ---

# %% [markdown]
# 1.- Hacer un programa que reciba dos números desde el teclado y responda "El número xxx divide (no divide) a yyy" ejecutando una función que devuelva verdadero si el primero divide al segundo.

# %% [markdown]
# 2.- Hacer un programa que responda:
#
# "El número xxx divide (no divide) a yyy" o
#
# "El número yyy divide (no divide) a xxx" o
#
# "Ninguno de los dos números divide al otro"
#
# utilizando la función anterior

# %% [markdown]
# 3.- Hacer un programa que reciba un número desde el teclado y ejecutando la función anterior, devuelva la lista de los divisores del número ingresado.

# %% [markdown]
# 4.- Utilizando la función anterior hacer otra que devuelva verdadero si el número recibido por parámetro es primo.

# %% [markdown]
# 5.- Utilizar las dos funciones anteriores ( "divide_a" y "es_primo" ) para hacer un programa que reciba un número por teclado y devuelva todos los números primos que lo dividen.

# %% [markdown]
# 6.- Utilizando las funciones desarrolladas hasta ahora, hacer un programa que reciba dos números desde el teclado y devuelva si son coprimos.

# %% [markdown]
# 7.-
# Hacer una función que calcule el interés de una inversión recibiendo por parámetro el capital, la TNA y la cantidad de días.
#
# Hacer un programa que reciba los tres parámetros de una inversión por teclado devuelva el interés.
#
# Hacer un programa que reciba los parámetros de dos inversiones y devuelva cuál es la más conveniente (paga más interés)

# %% [markdown]
# 8.- Hacer una función FdeX que calcule 3*X+2 y otra función GdeX que calcule -X+5. Luego hacer un programa que utilizando estas dos funciones, reciba por teclado un valor de X y devuelva FdeX compuesta con GdeX para el valor ingresado y 10 valores de X más, incrementados de a dos en cada iteración.

# %% [markdown]
# ##Ejercicios resueltos

# %%
# Ejercicio 1 - funcion
def divide_a(x,y):
 if y%x == 0:         # MODULO
    return True
 else:
    return False

# %%
# Ejercicio 1 - programa
x=int(input("Ingrese entero x="))
y=int(input("Ingrese entero y="))

if divide_a(x,y):
  print ("x=",x," divide a ","y=",y)
else:
  print ("x=",x," NO divide a ","y=",y)

if 3==3
# Out:
# Ingrese entero x=3
# Ingrese entero y=15
# x= 3  divide a  y= 15

# %%
#Ejercicio 4 - funcion
import numpy as np
def es_primo(n):
    i=2
   #while not divide_a(i,n) and i<n:
   #while not divide_a(i,n) and i<pow(n, 1/2):
    while not divide_a(i,n) and i<np.sqrt(n):
       i+=1
   #if i==n:
   #if i>pow(n, 1/2):
    if i>np.sqrt(n):
        return True
    else:
        return False

# %%
# Ejercicio 4 - programa
nro=1
if es_primo(nro):
  print ("nro=",nro," es primo")
else:
  print ("nro=",nro," NO es primo")

nro=2
if es_primo(nro):
  print ("nro=",nro," es primo")
else:
  print ("nro=",nro," NO es primo")

nro=3
if es_primo(nro):
  print ("nro=",nro," es primo")
else:
  print ("nro=",nro," NO es primo")

nro=4
if es_primo(nro):
  print ("nro=",nro," es primo")
else:
  print ("nro=",nro," NO es primo")


# Recibe un número por teclado
nro=int(input("Ingrese entero nro="))

if nro==1:
  print ("nro=",nro," NO, NO es primo")

if es_primo(nro):
  print ("nro=",nro," es primo")
else:
  print ("nro=",nro," NO es primo")
# Out:
# nro= 1  es primo
# nro= 2  es primo
# nro= 3  es primo
# nro= 4  NO es primo
# Ingrese entero nro=1
# nro= 1  NO, NO es primo
# nro= 1  es primo
